# %% [markdown]
# **Корректность проверена на Python 3.6:**
# + pandas 0.23.4
# + numpy 1.15.4
# + xgboost 0.81
# + sklearn 0.20.2

# %% [markdown]
# # Sklearn, XGBoost

# %% [markdown]
# ## sklearn.ensemble.RandomForestClassifier

# %%
from sklearn import ensemble, model_selection, metrics 

import numpy as np
import pandas as pd
import xgboost as xgb

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Данные

# %% [markdown]
# Задача на kaggle: https://www.kaggle.com/c/bioresponse
#
# Данные: https://www.kaggle.com/c/bioresponse/data
#
# По данным характеристикам молекулы требуется определить, будет ли дан биологический ответ (biological response).
#
# Признаки нормализаваны.
#
# Для демонстрации используется обучающая выборка из исходных данных train.csv, файл с данными прилагается.

# %%
bioresponce = pd.read_csv('bioresponse.csv', header=0, sep=',')

# %%
bioresponce.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...      0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...      1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...      0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...      0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
# 2      0      0      0
# 3      0      0      0
# 4      0      0      0
#
# [5 rows x 1777 columns]

# %%
bioresponce_target = bioresponce.Activity.values

# %%
bioresponce_data = bioresponce.iloc[:, 1:]

# %% [markdown]
# ### Модель RandomForestClassifier

# %% [markdown]
# #### Зависимость качества от количества деревьев

# %%
n_trees = [1] + list(range(10, 55, 5))

# %%
# %%time
scoring = []
for n_tree in n_trees:
    estimator = ensemble.RandomForestClassifier(n_estimators = n_tree, min_samples_split=5, random_state=1)
    score = model_selection.cross_val_score(estimator, bioresponce_data, bioresponce_target, 
                                             scoring = 'accuracy', cv = 3)    
    scoring.append(score)
scoring = np.asmatrix(scoring)
# Out:
# CPU times: user 11.8 s, sys: 1.04 s, total: 12.8 s
# Wall time: 12.8 s

# %%
pylab.plot(n_trees, scoring.mean(axis = 1), marker='.', label='RandomForest')
pylab.grid(True)
pylab.xlabel('n_trees')
pylab.ylabel('score')
pylab.title('Accuracy score')
pylab.legend(loc='lower right')

# %% [markdown]
# #### Кривые обучения для деревьев большей глубины

# %%
# %%time
xgb_scoring = []
for n_tree in n_trees:
    estimator = xgb.XGBClassifier(learning_rate=0.1, max_depth=5, n_estimators=n_tree, min_child_weight=3)
    score = model_selection.cross_val_score(estimator, bioresponce_data, bioresponce_target, 
                                             scoring = 'accuracy', cv = 3)    
    xgb_scoring.append(score)
xgb_scoring = np.asmatrix(xgb_scoring)
# Out:
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
# ...
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# CPU times: user 30.3 s, sys: 1.22 s, total: 31.5 s
# Wall time: 2.87 s
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 433, in inner_f
#     return f(**kwargs)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/sklearn.py", line 1176, in fit
#     self._Booster = train(
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 189, in train
#     bst = _train_internal(params, dtrain,
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/training.py", line 51, in _train_internal
#     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1192, in __init__
#     self._validate_features(d)
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 2318, in _validate_features
#     if self.feature_names is None:
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1430, in feature_names
#     return self._get_feature_info("feature_name")
#   File "/Users/u18071043/.local/lib/python3.8/site-packages/xgboost/core.py", line 1409, in _get_feature_info
#     _LIB.XGBoosterGetStrFeatureInfo(
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 394, in __getattr__
#     func = self.__getitem__(name)
#   File "/Users/u18071043/.conda/envs/working_env/lib/python3.8/ctypes/__init__.py", line 399, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: dlsym(0x7fca5b21f530, XGBoosterGetStrFeatureInfo): symbol not found
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %%
xgb_scoring
# Out:
# matrix([[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]])

# %%
pylab.plot(n_trees, scoring.mean(axis = 1), marker='.', label='RandomForest')
pylab.plot(n_trees, xgb_scoring.mean(axis = 1), marker='.', label='XGBoost')
pylab.grid(True)
pylab.xlabel('n_trees')
pylab.ylabel('score')
pylab.title('Accuracy score')
pylab.legend(loc='lower right')

# %% [markdown]
# #### **Если Вас заинтересовал xgboost:**
# python api: http://xgboost.readthedocs.org/en/latest/python/python_api.html
#
# установка: http://xgboost.readthedocs.io/en/latest/build.html
