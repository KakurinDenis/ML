# %%
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
sns.set()
# %config Completer.use_jedi = False
import copy
from sklearn.preprocessing import LabelEncoder

# %%
dataset = pd.read_csv('../data/healthcare-dataset-stroke-data.csv')
target_name='stroke'
data = dataset.drop('stroke', axis=1)
target = dataset['stroke']
data.set_index('id', inplace=True)

# %%
data.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status
# id
# 9046           Urban             228.69  36.6  formerly smoked
# 51676          Rural             202.21   NaN     never smoked
# 31112          Rural             105.92  32.5     never smoked
# 60182          Urban             171.23  34.4           smokes
# 1665           Rural             174.12  24.0     never smoked

# %%
print('Размеры выборки: {}'.format(data.shape))
# Out:
# Размеры выборки: (5110, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5110 entries, 9046 to 44679
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   object
#  5   work_type          5110 non-null   object
#  6   Residence_type     5110 non-null   object
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     5110 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 439.1+ KB

# %% [markdown]
# ## Data parametres

# %%
data.isnull().any()
# Out:
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# Residence_type       False
# avg_glucose_level    False
# bmi                   True
# smoking_status       False
# dtype: bool

# %%
def feature_type(n_unique):
    if(n_unique==0): return 'null'
    elif(n_unique==1): return 'unary'
    elif(n_unique==2): return 'binary'
    elif(n_unique<=8): return 'categorial'
    else: return 'interval'

# %%
params_dict = [{'feature_name': x,
              'null_abs' : len(data[data[x].isnull()]),
               'null_percentage' : 100*round(len(data[data[x].isnull()])/len(data), 4),
                'n_unique' : data[x].nunique(),
                'feature_type' : feature_type(data[x].nunique())
               }
              for x in data.columns]

# %%
df_stat = pd.DataFrame.from_dict(params_dict)
df_stat
# Out:
#         feature_name  null_abs  null_percentage  n_unique feature_type
# 0             gender         0             0.00         3   categorial
# 1                age         0             0.00       104     interval
# 2       hypertension         0             0.00         2       binary
# 3      heart_disease         0             0.00         2       binary
# 4       ever_married         0             0.00         2       binary
# 5          work_type         0             0.00         5   categorial
# 6     Residence_type         0             0.00         2       binary
# 7  avg_glucose_level         0             0.00      3979     interval
# 8                bmi       201             3.93       418     interval
# 9     smoking_status         0             0.00         4   categorial

# %%
binary_cols = df_stat['feature_name'][df_stat.feature_type=='binary'].values
unary_cols = df_stat['feature_name'][df_stat.feature_type=='unary'].values
categorial_cols = df_stat['feature_name'][df_stat.feature_type=='categorial'].values
interval_cols = df_stat['feature_name'][df_stat.feature_type=='interval'].values

# %%
#пример вывода статистик по фичам определенного типа
df_stat[df_stat.feature_name.isin(interval_cols)]
# Out:
#         feature_name  null_abs  null_percentage  n_unique feature_type
# 1                age         0             0.00       104     interval
# 7  avg_glucose_level         0             0.00      3979     interval
# 8                bmi       201             3.93       418     interval

# %% [markdown]
# ## Working with interval features

# %%
data[interval_cols].describe()
# Out:
#                age  avg_glucose_level          bmi
# count  5110.000000        5110.000000  4909.000000
# mean     43.226614         106.147677    28.893237
# std      22.612647          45.283560     7.854067
# min       0.080000          55.120000    10.300000
# 25%      25.000000          77.245000    23.500000
# 50%      45.000000          91.885000    28.100000
# 75%      61.000000         114.090000    33.100000
# max      82.000000         271.740000    97.600000

# %%
data[interval_cols].corr()
# Out:
#                         age  avg_glucose_level       bmi
# age                1.000000           0.238171  0.333398
# avg_glucose_level  0.238171           1.000000  0.175502
# bmi                0.333398           0.175502  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data[interval_cols].corr())
plt.show()

# %% [markdown]
# #### boxplot

# %%
ig, axes = plt.subplots(nrows=len(interval_cols), ncols=1, figsize=(20, 25))
for idx, feature in enumerate(interval_cols):
    sns.boxplot(x=data[feature], color='lightblue', ax=axes[idx])

# %% [markdown]
# ### distribution

# %%
fig, axes = plt.subplots(nrows=len(interval_cols), ncols=1, figsize=(20, 25))
for idx, feature in enumerate(interval_cols):
    sns.histplot(x=dataset[feature], hue=dataset[target_name], 
                palette=[(0.255,0,0.255), (0,0, 0.255)],
                edgecolor='black', ax=axes[idx])

# %%
sns.pairplot(data[interval_cols])
plt.show()

# %% [markdown]
# ## Working with categorial features

# %%
fig, axes = plt.subplots(nrows=len(categorial_cols), ncols=1, figsize=(20, 25))
for idx, feature in enumerate(categorial_cols):
    sns.countplot(x=feature, hue=target_name, data=dataset, ax=axes[idx], palette='ch:.25', edgecolor='black')

# %% [markdown]
# ## Working with binary features

# %%
fig, axes = plt.subplots(nrows=len(binary_cols), ncols=1, figsize=(20, 25))
for idx, feature in enumerate(binary_cols):
    sns.countplot(x=feature, hue=target_name, data=dataset, ax=axes[idx], edgecolor='black')

# %% [markdown]
# ## Working with target

# %%
plt.figure(figsize=(11,8))
sns.countplot(x=target_name, data=dataset, edgecolor='black')
plt.show()

# %% [markdown]
# ### Label encoding for pairplot

# %%
# Label encoding the variables before doing a pairplot
#because pairplot ignores strings
data_encoded = copy.deepcopy(dataset)
data_encoded.loc[:, categorial_cols] = data_encoded.loc[:, categorial_cols].apply(LabelEncoder().fit_transform)
data_encoded.loc[:, binary_cols] = data_encoded.loc[:, binary_cols].apply(LabelEncoder().fit_transform)

# %%
sns.pairplot(data_encoded)
